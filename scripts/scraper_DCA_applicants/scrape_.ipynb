# %% [markdown]
# all_applicant_scraping_data

# %%
import os
import time
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Base URL for funding applications
BASE_URL = "https://dca.georgia.gov"

# Specific funding page
FUNDING_CYCLE_PAGE = f"{BASE_URL}/applications-funding-and-funding-cycle-selections"

# Define years and types of applications
YEARS = list(range(2010, 2025))  # 1996 to 2024
APPLICATION_TYPES = ["4-core", "9-core"]

# Directories for downloads and logs
BASE_DOWNLOAD_DIR = os.path.join(os.getcwd(), "data", "applications_submitted")
LOG_FILE = os.path.join(BASE_DOWNLOAD_DIR, "not_found_pages.txt")

# Set up Chrome options
chrome_options = Options()
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--window-size=1920x1080")
chrome_options.add_experimental_option("prefs", {
    "safebrowsing.enabled": True
})

# Initialize WebDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)


def scrape_application_pages():
    """Scrapes application pages from 1996 to 2024 and downloads documents."""
    not_found_pages = []

    for year in YEARS:
        for app_type in APPLICATION_TYPES:
            page_url = f"{BASE_URL}/{year}-{app_type}-applications-submitted"

            print(f"Processing: {page_url}")

            try:
                driver.get(page_url)
                time.sleep(5)  # Allow time for page to load

                # Check if page exists
                if "Page not found" in driver.page_source or "The requested page could not be found" in driver.page_source:
                    print(f"Page not found: {page_url}")
                    not_found_pages.append(page_url)
                    continue

                # Find all downloadable document links
                document_links = [
                    link.get_attribute("href")
                    for link in driver.find_elements(By.TAG_NAME, "a")
                    if link.get_attribute("href") and (
                        ".xlsx" in link.get_attribute("href") or
                        ".pdf" in link.get_attribute("href") or
                        ".docx" in link.get_attribute("href") or
                        "download" in link.get_attribute("href")
                    )
                ]

                if not document_links:
                    print(f"No documents found on {page_url}")
                    not_found_pages.append(page_url)  # Log as empty page
                    continue

                print(f"Found {len(document_links)} documents on {page_url}")

                # Create directory only if files exist
                download_dir = os.path.join(BASE_DOWNLOAD_DIR, f"{year}_{app_type}")
                os.makedirs(download_dir, exist_ok=True)

                # Click each download link
                for doc_url in document_links:
                    click_download_link(doc_url)

            except Exception as e:
                print(f"Error processing {page_url}: {e}")

    # Save log of missing pages
    if not_found_pages:
        with open(LOG_FILE, "w", encoding="utf-8") as log:
            log.write("\n".join(not_found_pages))
        print(f"Missing pages recorded in {LOG_FILE}")

    driver.quit()


def scrape_funding_cycle_page():
    """Scrapes the 'Applications for Funding and Funding Cycle Selections' page."""
    print(f"Processing: {FUNDING_CYCLE_PAGE}")

    try:
        driver.get(FUNDING_CYCLE_PAGE)
        time.sleep(8)

        # Find all downloadable document links
        document_links = [
            link.get_attribute("href")
            for link in driver.find_elements(By.TAG_NAME, "a")
            if link.get_attribute("href") and (
                ".xlsx" in link.get_attribute("href") or
                ".pdf" in link.get_attribute("href") or
                ".docx" in link.get_attribute("href") or
                "download" in link.get_attribute("href")
            )
        ]

        if not document_links:
            print(f"No documents found on {FUNDING_CYCLE_PAGE}")
            return

        print(f"Found {len(document_links)} documents on {FUNDING_CYCLE_PAGE}")

        # Create directory only if files exist
        download_dir = os.path.join(BASE_DOWNLOAD_DIR, "funding_cycle_selections")
        os.makedirs(download_dir, exist_ok=True)

        # Click each download link
        for doc_url in document_links:
            click_download_link(doc_url)

    except Exception as e:
        print(f"Error processing {FUNDING_CYCLE_PAGE}: {e}")


def click_download_link(url):
    """Clicks on a download link to trigger file download."""
    try:
        print(f"Downloading: {url}")

        # Open each link in a new tab and trigger download
        driver.execute_script(f"window.open('{url}', '_blank');")
        time.sleep(5)  # Wait longer for download to start

    except Exception as e:
        print(f"Error downloading {url}: {e}")

    # Wait to ensure downloads finish before closing browser
    time.sleep(12)
# Out:
# Processing: https://dca.georgia.gov/2010-4-core-applications-submitted
# No documents found on https://dca.georgia.gov/2010-4-core-applications-submitted
# Processing: https://dca.georgia.gov/2010-9-core-applications-submitted
# Found 72 documents on https://dca.georgia.gov/2010-9-core-applications-submitted
# Downloading: https://dca.georgia.gov/document/forms/2010-001washingtonestatesiigoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-002ferrylakeestatesgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-003brookhaveniiigoracorexls/download
# Downloading: https://dca.georgia.gov/document/resources/2010-004gatewaypinesgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-005walnutsquaregoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-006maplesquaregoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-007sanfordplacegoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-008azaleamillgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-009heritagevistagoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-010cherokeemillloftsgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-011cottonmillloftsgoracorexls/download
# Downloading: https://dca.georgia.gov/document/resources/2010-012ellijayeastgoracorexls/download
# Downloading: https://dca.georgia.gov/document/resources/2010-013capitolviewsrgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-014windsorgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-015windwoodvillasgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-016hamptonoaksgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-017pinelakesrgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-018savannahgdnsph3goracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-019calypsogoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-020baptistgdnsgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-021fitgeraldsummitgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-022pepperridgegoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-023tanglewoodgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-024rochellegoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-025bakervillage3goracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-026columbthedgewd2goracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-027lanemanorgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-028emeraldgladegoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-029eastriversqgoracorexls/download
# Downloading: https://dca.georgia.gov/document/resources/2010-030kingslandph3sfgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-031briarcliffsummitgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-032magnoliatracegoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-033residencesstillwoodgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-034stillwaterpointgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-035oaktracevillasgoracorexls/download
# Downloading: https://dca.georgia.gov/document/resources/2010-036serenityterracecorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-037underwdhomesredevigoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-038legacywaltonterracegoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-039cortezvillasgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-040silverwoodplacegoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-041greenmtnvillagegoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-042potemkinsrvllgforsythgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-043villagewalkersbendgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-044crestpinehurstgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-045harmonygreenegoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-046hartsfieldlandinggoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-047heritagejohnscrkwalkgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-048brentwoodplacegoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-049altabradleyparkgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-050eaglesrunphigoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-051ivywoodparkgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-052maplewoodparkgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-053baywoodparkgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-054phoenixhousexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-055verandaunivrstyhomesgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-056saratogacourtph2goracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-057faithcrossinggoracorexls/download
# Downloading: https://dca.georgia.gov/document/resources/2010-058gracecrossinggoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-059farmingtonhillsgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-060farmingtonwoodsgoracorexls/download
# Downloading: https://dca.georgia.gov/document/resources/2010-061freedomspathgoracorexls/download
# Downloading: https://dca.georgia.gov/document/resources/2010-062jrobinsonsrgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-063retreatcandlervllggoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-064dixiehillssrmanorgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-065highlandmanorgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-066connerssrvllggoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-067forrestersrvllggoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-068fernpointgoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-069cypresslandinggoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-070goshencrossinggoracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-071allenwilsonph2goracorexls/download
# Downloading: https://dca.georgia.gov/document/forms/2010-072parkcrestterracegoracorexls/download
# Processing: https://dca.georgia.gov/2011-4-core-applications-submitted
# No documents found on https://dca.georgia.gov/2011-4-core-applications-submitted
# Processing: https://dca.georgia.gov/2011-9-core-applications-submitted
# Found 63 documents on https://dca.georgia.gov/2011-9-core-applications-submitted
# Downloading: https://dca.georgia.gov/document/forms/2011-001lafayettesrvllggoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-002myrtleterracesgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-003pecanpointgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-004plantationivgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-005ivywoodparkgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-006tanglewoodparkgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2011-007cherokeemillloftsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-008monroeelementarygoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-009countrygrovegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-010rochellegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-011deerfieldgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-012veteransrhsgalgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-013ashleyauburnpteiicorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-014rollingwoodplacegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-015briarcliffsummitgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-016farmingtonhillsphaseiixlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-017farmingtonwoodsxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-018creekviewcommonscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-019stonyridgeapartmentscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-020heritagevistaapartmentscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-021verandacentennialplcgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-022oakhammockgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-023villagewindingrdgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-024woodvale3goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-025edenfieldplacegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-026gatewaypines2goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-027chestnutvillagegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-028endeavorpointegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-029forestyorkgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-030watertowerpkgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-031columbiamillgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-032eastmangardensgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-033adaircourtgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-034woodsmillgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-035windridgegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-036oakforestgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-037alsobrooksrvllggoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-038thomsonestatesgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-039washingtonestates2goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2011-040mariasrgdnsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-041townctrheightsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-042renaissancehendrsngoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-043calypsogoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-044brentwoodplacegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2011-045oakcovecollegestngoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-046ringgold64goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-047lookoutpointegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-048redbirdpointegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-049stratfordcourtgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-050hearthsideptreecitygoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-051goldenhillsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-052foxwoodsrvllggoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-053hamptoncourtgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-054verandablacksheargoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-055etowahgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2011-056brunswicktaragoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-057heritageeastpauldggoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-058emeraldestatesgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-059powellspointegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-060capitoloakssrgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-061ashtonpinesgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-063coralgardensgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2011-064imperialhotelgoracorexlsx/download
# Processing: https://dca.georgia.gov/2012-4-core-applications-submitted
# No documents found on https://dca.georgia.gov/2012-4-core-applications-submitted
# Processing: https://dca.georgia.gov/2012-9-core-applications-submitted
# Found 62 documents on https://dca.georgia.gov/2012-9-core-applications-submitted
# Downloading: https://dca.georgia.gov/document/forms/2012-001stonridgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-002pinevillgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-003hardinterracegoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-004norwchcomgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-005presrvogeegoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-006hidglengoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-007tanghtsgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-008savgardivgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-009pinelakesrgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-010ovrlkwalkbndgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-011crkvcomgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-012csviigoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2012-013msvgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-014newcolfhgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2012-015pauldoeigoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-016monroeelemgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-017cherokeemillgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-018poplarptegoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-019waltonoaks2goraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2012-020wdlndsvlgiigoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-021hertgtrcgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-022mntviewgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-023stonevllygoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-024avlncrtgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-025brkhvngoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-026redbpgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-027broadvcgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-028vergrovwaygoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-029grovesplgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-030tallptegoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2012-031freedomptegoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-032eurhtsgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-033ashhsegoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-034aalatscholarswalgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-035goshcrossiigoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-036abbwoodsgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-037aubhillsgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-038farmhills2goraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-039brsltncrtgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-040hrthsdsgrlfgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-041lawrencevillesrgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-042adairctgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-043ftzsmtgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-044blackshrgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-045stanfordgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-046panolagardensgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-047magnoliaptgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-048thomsonestatesgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-049piedmontvillagegoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2012-050stillwellvillasgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2012-051freedmspth2goraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-052freedmspthigoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-053bearcrkvgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2012-054ramsrungoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-055ashleighplacegoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-056silcomgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-057myrtergoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-058lafsrgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-059allenwilson3goraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-060camct3goraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-061taragoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2012-062autumnmanorgoraxlsx/download
# Processing: https://dca.georgia.gov/2013-4-core-applications-submitted
# Found 4 documents on https://dca.georgia.gov/2013-4-core-applications-submitted
# Downloading: https://dca.georgia.gov/document/forms/2012-501trestltreecorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2013-502provpkwyvlgcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2013-503oakforestcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2013-506reynoldstownsrcorepdf/download
# Processing: https://dca.georgia.gov/2013-9-core-applications-submitted
# Found 53 documents on https://dca.georgia.gov/2013-9-core-applications-submitted
# Downloading: https://dca.georgia.gov/document/forms/2013-001forestmillcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-002commonsatnelmscoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-003manoratbroadcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2013-004gdnsyghrscoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-005stanfordcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-006hamptoncoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-007cntrygrovecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-008stonevllycoreappgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-009savgardvcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-010heathhighcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-011mtnvwsrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-012wildpinescoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2013-013tupeloridgecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-014schoolstdevcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2013-015lgcywaltoakiicoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-016silcomcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-017eurhtscoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-018autrypinescoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-019chapicoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-020pauldoeiicoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2013-021farmforestcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2013-022jacksonhillscoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-023autumntracecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-024jenmilcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-025harcomcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-026brdvwcvecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2013-027allenrdcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2013-028grovelandterrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2013-029toccterrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-030grovesplcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-031tobiesnrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-032hthsdtckrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-033lemerroylcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2013-034pntnrthsrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-035nrthlksrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-036davdsnsnrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-037meriwethercoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-038ashleighcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-039waverlyterrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2013-040greystonecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-041crkvlgcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-042walntwaycoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-043romanarileycoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-044renaisnprkcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-045willghmvillgcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-046abbtrailcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-047bethvlgcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-048hrznsrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-049centenlpl2coregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-050greenptecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-051boynvlgcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-052mryleilatcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2013-053centenlpl1coregoraxlsx/download
# Processing: https://dca.georgia.gov/2014-4-core-applications-submitted
# Found 25 documents on https://dca.georgia.gov/2014-4-core-applications-submitted
# Downloading: https://dca.georgia.gov/document/forms/2014-501harborsqcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-502sablechasecorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-503ashtnrichhillcorerevised730pdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-504cxcrkcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-505crestviewmanorcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-506pigeonbluffcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-507briercrkcorepdf/download
# Downloading: https://dca.georgia.gov/document/resources/2014-508coxcrkcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-509crestvwmanorcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-510fairfieldcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-511forestptecorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-512forestrdgecorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-513heritagemanorcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-514heritageoakscorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-515hiddencrkcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-516lafayettegdnscorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-517meadowwdcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-518peppertonvillascorepdf/download
# Downloading: https://dca.georgia.gov/document/resources/2014-519pigeonbluffcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-520pigeoncrkcorepdf/download
# Downloading: https://dca.georgia.gov/document/resources/2014-521pinebrookcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-522tanyard2corepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-523wamsprgscorepdf/download
# Downloading: https://dca.georgia.gov/document/resources/2014-524wildwoodcorepdf/download
# Downloading: https://dca.georgia.gov/document/forms/2014-525woodlandterrcorepdf/download
# Processing: https://dca.georgia.gov/2014-9-core-applications-submitted
# Found 57 documents on https://dca.georgia.gov/2014-9-core-applications-submitted
# Downloading: https://dca.georgia.gov/document/forms/2014-001lakevwgdnsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-002sumterststngoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2014-003romonarileygoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-004sawmillldggoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-005mdwscmillagoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-006northgrovegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-007hitchphigoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-008grovesplcgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2014-009mallardlakesgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-010willowbrookgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-011peytonrdggoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-012librtyplcgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-013greenlfpkgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-014silverlakegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-015chapmanpiigoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-016pauldoepiiigoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-017cmpbllplcgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-018wtrtwrpksrgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-019masonmanorgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-020rollingwdplcgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-021wisteriaplcgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-022willwbrkmdwsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2014-023oliverplcgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-024hsevermoregoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-025bearcrkvlggoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-026clarkesstngoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-027newpttrcgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-028hghldgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2014-029peachvillasamergoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-030summerbrzpkgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-031ovrlkwlkrsbdgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-032davdsnsrmanorgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-033sthwstrngoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-034westhvniigoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-035grantstdevgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2014-03615stdevp1goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-037sistersctgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-038huntschlgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-039willghmvlgiigoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-040sthfrkgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-041hghptegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-042centlpl2goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-043vergrovwygoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-044wellgtnwaygoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-045forestvwgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-046potmknwr2goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-047sterlghtsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-048oscarthomiegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-049frdmpthgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-050retreatmillscrkgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-051macongrdngoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-052almillervlggoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-053ptenrthvlgp2goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-054parksrvlggoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-055trinitywk1goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-056sthromegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2014-057willwcrkgoracorexlsx/download
# Processing: https://dca.georgia.gov/2015-4-core-applications-submitted
# Found 7 documents on https://dca.georgia.gov/2015-4-core-applications-submitted
# Downloading: https://dca.georgia.gov/document/forms/2015-501pinewoodgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-502cherokeesprgsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-503grayfldgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-506remingtongoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-507cumberldoaksgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-508gdnhvptgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-509wessblckgoracorexlsx/download
# Processing: https://dca.georgia.gov/2015-9-core-applications-submitted
# Found 75 documents on https://dca.georgia.gov/2015-9-core-applications-submitted
# Downloading: https://dca.georgia.gov/document/forms/2015-001clvrlfcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-002telfairarmscoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-003clarkstncoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-004allenparkcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-005oxfordcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2015-006oakmontcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-007westdalecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-008kentoncoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-009yorkcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-010lkvwgrdnscoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-011fxwrthcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-012indcrkcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2015-013capvwcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-014hitchphiicoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-015breckoakscoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-016fellwdcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-017centplc3coregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2015-018romrilcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-019wndrdiicoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-020stoneridgeaptscoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-021villagegrveprkcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-022champcrkcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-023tarrgrnecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2015-024mallaptecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-025mdwsblrsvlcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-026arbrtrciicoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-027wariiiaptscoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-028grancrsgcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-029hardinterrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-030tnvwcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-031grnrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-032wsthvncoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-033mktstncoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-034ashcrscoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-035willowcrkcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-036chndlrtrccoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-037tindallsrtwrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-038emplccoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-039pglndgcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-040avondalecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-041junipercoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-042promsrvlgcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-043ptenthvlgp2coregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-044grvsrvlgcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-04515stdevp1coregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-046240atlstdevp1coregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-047antsumcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-048peytonridgecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-049benhillcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-050ovrlkwbcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-051redoakcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-052midwaycoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-053mdlkplcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-054ablnpkcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-055sromecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-056lakeviewcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-057lakesidecrkcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-058villanorthcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-059oaksatnorthintowncoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-060hutcrsgadcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-061mcrhelestcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-062tw2coregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-063wellwaycoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-0641657whcirdevp1coregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-065abbridgecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-066abbhawcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-067hghldtrccoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-068bearcreekvcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-069butlerstycoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2015-070lagrangemfcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-071meriwthr2coregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-072phnxhsecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-073citylights2coregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2015-074wlshrplcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2015-075srresidencesmercypkcoregoraxlsx/download
# Processing: https://dca.georgia.gov/2016-4-core-applications-submitted
# Found 24 documents on https://dca.georgia.gov/2016-4-core-applications-submitted
# Downloading: https://dca.georgia.gov/document/forms/2016-502rdatwrcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-503-506hacgradmastercoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-503farleyradcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-504knightradcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-505wilsonradcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-506wilsonradcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2016-507pineswestdalecorev4goraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-508capitolvwgtwycoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2016-509peachorchcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-510keystonecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-511exchangecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2016-512sterlingcandlercoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-513brookfieldmewsgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-514paradiseeastgoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-515pinevillageigoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-516swftcrkcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2016-517prkwstcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-518maggiecapitolcoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-519newvlgsconleyhncoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-520hnoasiscoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2016-521hnctylghts2coregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-522hnbrtstonecoregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-523hnlucymorgan2coregoraxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-524wheatstcoregoraxlsx/download
# Processing: https://dca.georgia.gov/2016-9-core-applications-submitted
# Found 79 documents on https://dca.georgia.gov/2016-9-core-applications-submitted
# Downloading: https://dca.georgia.gov/document/forms/2016-001hacgradwwmsrvrsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-002zebulongoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2016-003laurelislandgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-004mtnviewgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2016-005indcrk2goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-006campbellrdggoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-007nelmsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-008wndgrdiigoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-009coventrygoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-010newportgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-011champcrkgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-012ridgecrestgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-013romrilgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-014brittanypkgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-015whcirdevp2goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-016benhillgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-017ovlkwlkrbndgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-018scottsrgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-019madhtsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-020tayvlggoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-021pioneerplcgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-022breakersgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-023gdnsmcngoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-024redcrkvlsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-025tupelogoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-026kingslandvllggoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-027maconnorthgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-028vlgprkgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-029woodmeadtowngoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-030pinevillageiigoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-031oxvillaptsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-032240atlstdevp2goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-03315thstdevp2goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-034adairctgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-035tarrgrnegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/resources/2016-036oaksatnorthigoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-037oscarthomiegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-038frehtsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-039ashcvegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-040pkscrngoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-041pksoakgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-042pkswaygoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-043tindallfldsp1goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-044lkvwsrgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-045pinetrailsgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-046ashschlrlndg1goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-047twnprkgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-048hrtgpntgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-049lrchawkgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-050lovejoygoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-051wistmabgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-052hslafayettegoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-053kdintvlggoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-054nthlksrgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-055tw3goracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-056kingscrnrgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-057cntroksgoracorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2016-058acwrthcmnsgoracorexlsx/download
# ...
# Downloading: https://dca.georgia.gov/document/forms/2023-544asburypt4pctcoreseptxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-545eleacorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-546autumnln4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-547bartonvlg4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-548brkshollow4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-549brightwdln4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-550carriagehill4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-551foresthills4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-552greenwdvlg4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-553jasmineln4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-554marshallln4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-555meadowbrkln4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-556oakln4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-557pecangrove4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-558tanyrdbrchi4pctcorexlsx/download
# Processing: https://dca.georgia.gov/2023-9-core-applications-submitted
# Found 81 documents on https://dca.georgia.gov/2023-9-core-applications-submitted
# Downloading: https://dca.georgia.gov/document/forms/2023-001johngrhmcoreappxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-002vlglgcyp2corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-003wilshire2corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-004finleyplacecorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-005sentrycorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-006helixcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-007pksdouglsvllecorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-008cavesprngcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-009pinewdpkcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-010charltnctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-011hilmntcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-0121700draytonstcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-013hardintrc29pctcoreaprilfinalxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-014abbcrtcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-015mdngststncorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-016hdcklndgcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-017hollywoodcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-018watsonptecorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-019csstcrsngcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-020oaksidecorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-021villascambornecorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-022bridgeslincomcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-023springcrkcmnscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-024westchestervllgcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-025valleytrailcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-026westpinesrsdnccorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-027bobbyjnsvllascorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-028ashleymidtowncorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-029grove2corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-030owenslndgcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-031fpaugiiiappxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-032ovrlkelljy9pctcoreaprilfinalxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-033heritagecoreapplihtcpresvxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-033heritagecoreappusdapresvxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-034princetonctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-035hampte9pctcoreaprilfinalxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-036wltnwaycrsgcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-037hillsidecorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-038mdwdprkcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-039carmiccmnsii9pctcoreaprilfinalxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-040mcauleypkp2corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-041rharedevp1corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-042gatewaylndgcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-043dglssschlsrcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-044maplerdgcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-045oakrdgrsrvcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-046lafayettevllgcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-047magnoliaplccorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-048parcsolomoncorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-049masonhtscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-050jrjohnsonlgcyvllgcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-051wndsrcrsgcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-052wstptvllgiicorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-053hsrvrdl2corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-054magplccorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-055fairhvncmpbltncorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-056brkshollow9pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-057sprgvw9pctcoreaprilfinalxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-058chpmanfltsxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-058chpmanfltsxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-059bellwdterrcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-060stonehillcoreappxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-061tanyrdbrch1corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-062wesleysqcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-063houstonlkcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-064dogwdtrl2corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-065richmndsmmtcorehtcxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-065richmndsmmthudcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-066bonairhtccorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-066bonairhudcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-067berwicksr2corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-068blountcmmnscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-069hamhills2corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-070capstnhoneycrkcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-071lgcywltncrsg2corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-072lgcywltnvllgcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-073evertoncmmnscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-074harveststn2xlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-075davisexchcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-076gtwyglencoetrccorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-077gtwyhighlandpkcorexlsx/download
# Processing: https://dca.georgia.gov/2024-4-core-applications-submitted
# No documents found on https://dca.georgia.gov/2024-4-core-applications-submitted
# Processing: https://dca.georgia.gov/2024-9-core-applications-submitted
# Found 72 documents on https://dca.georgia.gov/2024-9-core-applications-submitted
# Downloading: https://dca.georgia.gov/document/forms/2024-001groveiicorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-002towervlgcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-003rharedevp2corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-004draytoncore5xlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-005cambornecore5xlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-006lincomcore5xlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-007azaleamdwscore5xlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-008summithckrycrkcore5xlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-009hrthsdriverdalecorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-010mooncreekcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-011arbrstwnbrchcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-012finleyplccorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-013shelbycorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-014wisthinesxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-015edmnddrvlecorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-016heritagecompetitivecorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-017timberrdgcompetitivecorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-018redlandtrccorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-019lakevw2corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-020mdngststncorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-021bryntslndngcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-022patvllestscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-023wstchtrplccorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-024watptecoreappxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-025csstacrsngcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-026lewisxgcoreappxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-027wslysqcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-028pncrstvlgcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-029perrycmmscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-030harborptcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-031sthrngdnscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-032capstnbluerdgecorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-033cpstnmagnoliacrkcorexlsx/download
# Downloading: https://dca.georgia.gov/document/form/2024-034westpine2corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-035librtycrssgxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-036berwicksriicorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-037jonesborocorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-038lakeviewcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-039retrtmcintoshfarmcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-040pleasnthillcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-041-excel-appxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-042hallsethmstncoreappxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-043-excel-appxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-044-hrvstniicorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-045-johngrhmxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-046-dogwdtrl2corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-047-clsscctyxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-048-dougpropxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-049-cvsprngxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-050-pecgrorhbcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-051pkselrodcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-052pksdahliicorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-053abbbrcore5xlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-054osprylndgscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-055hrdctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-056wndsrcrsgiicorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-057chattoogardgcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-058olvrnrth1xlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-059bnsncorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-060vlggrfocdcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-061cmms904corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-062fields1coreappxlsx/download
# Downloading: https://dca.georgia.gov/document/document/2024-063mgnliagrdnssrlvgxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-064hamhillsphsiicorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-065glncoetrceaptscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-066hghlndprksnrvlgaptscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-067magplcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-068nbvcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-069onepchtreesrcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-070wistgrdnsnewncorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2024-071sanctuarycore5xls/download
# Downloading: https://dca.georgia.gov/document/forms/2024-072fiftyfivecore5xlsx/download
# Missing pages recorded in /Users/sibilz/Desktop/000-MSQTM/QTM_25spring/550_1 quantitative science project /LIHTC/data/applications_submitted/not_found_pages.txt
# Processing: https://dca.georgia.gov/applications-funding-and-funding-cycle-selections
# Error processing https://dca.georgia.gov/applications-funding-and-funding-cycle-selections: HTTPConnectionPool(host='localhost', port=53753): Max retries exceeded with url: /session/20a45924f9851b3cb30bb42ed52a5938/url (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x130d392e0>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
if __name__ == "__main__":
    scrape_application_pages()  # Scrape funding applications (4% & 9% cycles)
    scrape_funding_cycle_page()  # Scrape "Applications for Funding and Funding Cycle Selections"

# %% [markdown]
# Move files into correct directories

# %% [markdown]
# Continue to scrape funding_cycle_page

# %%
import os
import time
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Base URL for funding applications
BASE_URL = "https://dca.georgia.gov"

# Specific funding page
FUNDING_CYCLE_PAGE = f"{BASE_URL}/applications-funding-and-funding-cycle-selections"

# Directories for downloads and logs
BASE_DOWNLOAD_DIR = os.path.join(os.getcwd(), "data", "applications-funding-and-funding-cycle-selection")
LOG_FILE = os.path.join(BASE_DOWNLOAD_DIR, "not_found_pages.txt")

# Set up Chrome options
chrome_options = Options()
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--window-size=1920x1080")
chrome_options.add_experimental_option("prefs", {
    "safebrowsing.enabled": True
})

# Initialize WebDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)



def scrape_funding_cycle_page():
    """Scrapes the 'Applications for Funding and Funding Cycle Selections' page."""
    print(f"Processing: {FUNDING_CYCLE_PAGE}")

    try:
        driver.get(FUNDING_CYCLE_PAGE)
        time.sleep(8)

        # Find all downloadable document links
        document_links = [
            link.get_attribute("href")
            for link in driver.find_elements(By.CLASS_NAME, "document-link__content"):
            if link.get_attribute("href") and (
                ".xlsx" in link.get_attribute("href") or
                ".pdf" in link.get_attribute("href") or
                ".docx" in link.get_attribute("href") or
                "download" in link.get_attribute("href")
            )
        ]

        if not document_links:
            print(f"No documents found on {FUNDING_CYCLE_PAGE}")
            return

        print(f"Found {len(document_links)} documents on {FUNDING_CYCLE_PAGE}")

        # Create directory only if files exist
        download_dir = os.path.join(BASE_DOWNLOAD_DIR, "funding_cycle_selections")
        os.makedirs(download_dir, exist_ok=True)

        # Click each download link
        for doc_url in document_links:
            click_download_link(doc_url)

    except Exception as e:
        print(f"Error processing {FUNDING_CYCLE_PAGE}: {e}")


def click_download_link(url):
    """Clicks on a download link to trigger file download."""
    try:
        print(f"Downloading: {url}")

        # Open each link in a new tab and trigger download
        driver.execute_script(f"window.open('{url}', '_blank');")
        time.sleep(5)  # Wait longer for download to start

    except Exception as e:
        print(f"Error downloading {url}: {e}")

    # Wait to ensure downloads finish before closing browser
    time.sleep(12)

# %%
scrape_funding_cycle_page()  # Scrape "Applications for Funding and Funding Cycle Selections"

# %% [markdown]
# ### PastScraping-2023-4

# %%
https://dca.georgia.gov/2023-4-core-applications-submitted

# %%
import os
import time
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
import os
import time
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from urllib.parse import urljoin

# Target webpage
BASE_URL = "https://dca.georgia.gov/2023-4-core-applications-submitted"

# Set up local directory to save files
DOWNLOAD_DIR = os.path.join(os.getcwd(), "data", "applications_submitted", "downloaded_files")
os.makedirs(DOWNLOAD_DIR, exist_ok=True)

# Set up Chrome options
chrome_options = Options()
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--window-size=1920x1080")
chrome_options.add_experimental_option("prefs", {
    "download.default_directory": DOWNLOAD_DIR,  # Set download directory
    "download.prompt_for_download": False,       # Auto-download files
    "safebrowsing.enabled": True
})

# Initialize WebDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# Open the webpage
driver.get(BASE_URL)

# Wait for page elements to load
time.sleep(5)

# Find all document links using Selenium
document_links = []
for link in driver.find_elements(By.TAG_NAME, "a"):
    href = link.get_attribute("href")
    if href and (".xlsx" in href or ".pdf" in href or ".docx" in href or "download" in href):
        document_links.append(href)

if not document_links:
    print("No documents found.")
else:
    print(f"Found {len(document_links)} documents.")

# Click each download link
for doc_url in document_links:
    try:
        print(f"Downloading: {doc_url}")

        # Open each link in a new tab and trigger download
        driver.execute_script(f"window.open('{doc_url}', '_blank');")
        time.sleep(3)  # Wait for the download to start

    except Exception as e:
        print(f"Error downloading {doc_url}: {e}")

# Wait for downloads to complete
time.sleep(10)

# Close the browser
driver.quit()

print(f"All files saved to: {DOWNLOAD_DIR}")
# Out:
# Found 57 documents.
# Downloading: https://dca.georgia.gov/document/forms/2023-501nthsidehills4pctcoreseptxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-502martinhse4pctcoreseptxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-503parishgrove4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-504oxford4pctcoreseptxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-505the3504pctcoreseptxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-506cnlcmns4pctcoreseptxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-507civicctrr1sr4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-508autumnridgeappxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-509columbusgrdns4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-510brdghwl4pctcoreseptxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-511westclubcoreappxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-512trinityflats4pctcoreaprilxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-513citylghtssthcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-514vrbnastredev4pctcoreseptxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-515garsonredevcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-516applewdtwrs4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-517herndonp3corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-518bluesky4pctcoreappxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-519hslivngfaith4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-520mlkseniorcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-521renaissanceppscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-523dls4pctcoreseptxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-524northdowniicorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-525capitolgtwyp1corexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-526ashcollegetownp1xlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-527havenbrkcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-528parksidewmscrkcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-529bwnhmscorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-530meadows1coreapp4pctxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-531hrvstniixlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-532westburycorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-533seacstapts4pctcoresexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-534jonesboro4pctcoreseptxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-535pkwynnplccorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-536parcrosenwld4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-537gtwylafayte4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-538vllgcrvriiicorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-539pinescorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-540bonair4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-541chosewdpkcoreapp4pctxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-542richsumm4pctcoreseptxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-543andoverplce4pctcoreseptxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-544asburypt4pctcoreseptxlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-545eleacorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-546autumnln4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-547bartonvlg4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-548brkshollow4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-549brightwdln4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-550carriagehill4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-551foresthills4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-552greenwdvlg4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-553jasmineln4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-554marshallln4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-555meadowbrkln4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-556oakln4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-557pecangrove4pctcorexlsx/download
# Downloading: https://dca.georgia.gov/document/forms/2023-558tanyrdbrchi4pctcorexlsx/download
# All files saved to: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files

# %%
# Target URL
BASE_URL = "https://dca.georgia.gov/2023-4-core-applications-submitted"

# Set up Chrome WebDriver options
chrome_options = Options()
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--window-size=1920x1080")

# Initialize WebDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# Open the webpage
driver.get(BASE_URL)

# Wait for elements to load
time.sleep(5)

# Get page source and parse with BeautifulSoup
soup = BeautifulSoup(driver.page_source, "html.parser")

# Close Selenium browser
driver.quit()

# Find all document links
document_links = []
for link in soup.find_all("a", href=True):
    href = link["href"]
    if href.endswith((".xlsx", ".xls", ".pdf", ".docx", ".csv")) or "download" in href:
        full_url = urljoin(BASE_URL, href)
        document_links.append(full_url)

if not document_links:
    print("No documents found.")
else:
    print(f"Found {len(document_links)} documents to download.")

# Create local directory for downloads
DOWNLOAD_DIR = os.path.join(os.getcwd(), "data", "applications_submitted", "downloaded_files")
os.makedirs(DOWNLOAD_DIR, exist_ok=True)

# Function to download files
def download_files(file_urls):
    for url in file_urls:
        try:
            filename = os.path.basename(url)
            file_path = os.path.join(DOWNLOAD_DIR, filename)

            print(f"Downloading: {filename}...")

            # Request file download
            response = requests.get(url, stream=True)
            response.raise_for_status()

            # Write to file
            with open(file_path, "wb") as file:
                for chunk in response.iter_content(chunk_size=8192):
                    file.write(chunk)

            print(f"Downloaded successfully: {file_path}")

        except requests.RequestException as e:
            print(f"Failed to download {url}: {e}")

# Start downloading files
download_files(document_links)
# Out:
# Found 57 documents to download.
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download
# Downloading: download...
# Downloaded successfully: /Users/sibilz/Desktop/000-MSQTM/QTM-24 fall courses /25spring /550_1 quantitative science project /LIHTC/data/applications_submitted/downloaded_files/download

# %%
# 启动 WebDriver
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# 访问 IMDb 页面（替换为你的 IMDb 网址）
url = "https://dca.georgia.gov/2023-4-core-applications-submitted"
driver.get(url)

# 获取完整 HTML 源代码
page_source = driver.page_source

# 将 HTML 保存到本地文件
with open("2023_applications_page.html", "w", encoding="utf-8") as file:
    file.write(page_source)

print("IMDb 页面 HTML 已保存为 imdb_page.html")
# Out:
# IMDb 页面 HTML 已保存为 imdb_page.html
